# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
main_url = 'https://www.premierleague.com/players/16431/player/stats'
result= requests.get(main_url)
result.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta name="twitter:title" content="Rúben Dias Statistics | Premier League"/>\n<meta name="keywords" content="Premier League, Football, Soccer, Official"/>\n<meta property="og:type" content="website"/>\n<meta name="description" content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League."/>\n<meta name="twitter:description" content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League."/>\n<meta name="twitter:image" content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png"/>\n<meta property="og:title" content="Rúben Dias Statistics | Premier League"/>\n<meta property="og:image" content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png"/>\n<meta name="theme-color" content="#38003C"/>\n<title>Rúben Dias Statistics | Premier League</title>\n<meta property="og:description" content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League."/>\n\n\t<!-- Designed and built by Pulselive - www.pulselive.com -->\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\n\t<script>\n\t\tdataLayer = [];\n\t\twindow.RESOURCE_VERSION = \'prod/83c6d67-3434\';\n\t</script>\n\t\n    <script src="//translations.platform.pulselive.com/premierleague/en.js" charset="UTF-8"></script>\n<!--[if gt IE 8]><!-->\n    <link rel="stylesheet" href="/resources/prod/83c6d67-3434/styles/badge-abbreviations.css">\n    <link rel="stylesheet" href="/resources/prod/83c6d67-3434/styles/screen.css">\n<!--<![endif]-->\n\n\t<!--[if lt IE 9]>\n\t\t<link rel="stylesheet" href="/resources/prod/83c6d67-3434/styles/ie-old.css">\n\t\t<script src="/resources/prod/83c6d67-3434/bower/html5shiv/dist/html5shiv.js"></script>\n\t<![endif]-->\n<script async=\'async\' src=\'https://www.googletagservices.com/tag/js/gpt.js\'></script>\n<script>\n  var googletag = googletag || {};\n  googletag.cmd = googletag.cmd || [];\n</script>\n\n\n\n\t\n\t\n\n\n\n    <link href="https://fonts.googleapis.com/css?family=Poppins:400,700" rel="stylesheet" type="text/css">\n\n\t<!-- Google Tag Manager -->\n    <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-MS75QT"\n    height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-MS75QT\');</script>\n    <!-- End Google Tag Manager -->\n\n\t<!-- Polyfill service provided by the FT - https://github.com/Financial-Times/polyfill-service -->\n\t<script src="//cdn.polyfill.io/v2/polyfill.min.js"></script>\n\n\t<!-- FastClick speeds up click bindings on touch screens by the FT - https://github.com/ftlabs/fastclick -->\n\t<script src="/resources/prod/83c6d67-3434/bower/fastclick/lib/fastclick.js"></script>\n\n\t<script src="/resources/prod/83c6d67-3434/bower/mustache.js/mustache.min.js"></script>\n\t<script src="/resources/prod/83c6d67-3434/bower/moment/min/moment-with-locales.min.js"></script>\n\t<script src="/resources/prod/83c6d67-3434/bower/moment-timezone/moment-timezone.js"></script>\n\t<script src="/resources/prod/83c6d67-3434/bower/object-fit-images/dist/ofi.browser.js"></script>\n\t<script src="/resources/prod/83c6d67-3434/bower/intersection-observer/polyfill/intersection-observer.js"></script>\n\n\t<link rel="apple-touch-icon-precomposed" sizes="57x57" href="/ ...

# %%
soup = BeautifulSoup(result.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Rúben Dias Statistics | Premier League" name="twitter:title"/>
#   <meta content="Premier League, Football, Soccer, Official" name="keywords"/>
#   <meta content="website" property="og:type"/>
#   <meta content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League." name="description"/>
#   <meta content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League." name="twitter:description"/>
#   <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" name="twitter:image"/>
#   <meta content="Rúben Dias Statistics | Premier League" property="og:title"/>
#   <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" property="og:image"/>
#   <meta content="#38003C" name="theme-color"/>
#   <title>
#    Rúben Dias Statistics | Premier League
#   </title>
#   <meta content="View stats of Manchester City Defender Rúben Dias, including goals scored, assists and appearances, on the official website of the Premier League." property="og:description"/>
#   <!-- Designed and built by Pulselive - www.pulselive.com -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script>
#    dataLayer = [];
# 		window.RESOURCE_VERSION = 'prod/83c6d67-3434';
#   </script>
#   <script charset="UTF-8" src="//translations.platform.pulselive.com/premierleague/en.js">
#   </script>
#   <!--[if gt IE 8]><!-->
#   <link href="/resources/prod/83c6d67-3434/styles/badge-abbreviations.css" rel="stylesheet"/>
#   <link href="/resources/prod/83c6d67-3434/styles/screen.css" rel="stylesheet"/>
#   <!--<![endif]-->
#   <!--[if lt IE 9]>
# 		<link rel="stylesheet" href="/resources/prod/83c6d67-3434/styles/ie-old.css">
# 		<script src="/resources/prod/83c6d67-3434/bower/html5shiv/dist/html5shiv.js"></script>
# 	<![endif]-->
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Poppins:400,700" rel="stylesheet" type="text/css"/>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MS75QT" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-MS75QT');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Polyfill service provided by the FT - https://github.com/Financial-Times/polyfill-service -->
#   <script src="//cdn.polyfill.io/v2/polyfill.min.js">
#   </script>
#   <!-- FastClick speeds up click bindings on touch screens by the FT - https://github.com/ftlabs/fastclick -->
#   <script src="/resources/prod/83c6d67-3434/bower/fastclick/lib/fastclick.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/bower/mustache.js/mustache.min.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/bower/moment/min/moment-with-locales.min.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/bower/moment-timezone/moment-timezone.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/bower/object-fit-images/dist/ofi.browser.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/bower/intersection-observer/polyfill/intersection-observer.js">
#   </script>
#   <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57">
#    <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114">
#     <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72">
#      <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
#      <link href="/resources/prod/83c6d67-3434/i/favicon/favicon.ico" rel="shortcut icon"/>
#      <meta content=" " name="application-name">
#       <meta content="#FFFFFF" name="msapplication-TileColor">
#        <meta content="mstile-144x144.png" name="msapplication-TileImage">
#         <meta content="mstile-70x70.png" name="msapplication-square70x70logo"/>
#         <meta content="mstile-150x150.png" name="msapplication-square150x150logo"/>
#         <meta content="mstile-310x150.png" name="msapplication-wide310x150logo"/>
#         <meta content="mstile-310x310.png" name="msapplication-square310x310logo"/>
#         <meta content="app-id=1138895159" name="apple-itunes-app"/>
#         <!--
# 	Enables or disables automatic detection of possible phone numbers in a webpage in Safari on iOS.
# 	https://developer.apple.com/library/content/documentation/AppleApplications/Reference/SafariHTMLRef/Articles/MetaTags.html#//apple_ref/doc/uid/TP40008193-SW5
# 	-->
#         <meta content="telephone=no" name="format-detection"/>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body>
#   <header class="masthead">
#    <a class="skipTo" href="#mainNav">
#     Skip to main navigation
#    </a>
#    <a class="skipTo" href="#mainContent">
#     Skip to main content
#    </a>
#    <nav class="clubNavigation" data-script="pl_global-header" role="menubar">
#     <div class="clubSitesHeading">
#      <!-- TO-TRANSLATE -->
#      <h4>
#       Club Sites
#       <div class="icon">
#       </div>
#      </h4>
#     </div>
#     <ul class="clubList" role="menu">
#      <li>
#       <a href="        http://www.arsenal.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t3@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t3.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t3@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Arsenal
#         </span>
#        </div>
#        <span class="name">
#         Arsenal
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.avfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t7@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t7.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t7@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Aston Villa
#         </span>
#        </div>
#        <span class="name">
#         Aston Villa
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.brightonandhovealbion.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t36@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t36.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t36@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Brighton &amp; Hove Albion
#         </span>
#        </div>
#        <span class="name">
#         Brighton &amp; Hove Albion
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.burnleyfootballclub.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t90.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t90@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t90.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t90@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Burnley
#         </span>
#        </div>
#        <span class="name">
#         Burnley
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.chelseafc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t8@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t8.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t8@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Chelsea
#         </span>
#        </div>
#        <span class="name">
#         Chelsea
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.cpfc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t31@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t31.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t31@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Crystal Palace
#         </span>
#        </div>
#        <span class="name">
#         Crystal Palace
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.evertonfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t11@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t11.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t11@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Everton
#         </span>
#        </div>
#        <span class="name">
#         Everton
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.fulhamfc.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t54@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t54.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t54@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Fulham
#         </span>
#        </div>
#        <span class="name">
#         Fulham
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.leedsunited.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t2.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t2@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t2.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t2@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Leeds United
#         </span>
#        </div>
#        <span class="name">
#         Leeds United
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.lcfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t13@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t13.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t13@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Leicester City
#         </span>
#        </div>
#        <span class="name">
#         Leicester City
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.liverpoolfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t14@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t14.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t14@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Liverpool
#         </span>
#        </div>
#        <span class="name">
#         Liverpool
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.mancity.com?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t43@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t43.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t43@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Manchester City
#         </span>
#        </div>
#        <span class="name">
#         Manchester City
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.manutd.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t1@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t1@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Manchester United
#         </span>
#        </div>
#        <span class="name">
#         Manchester United
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.nufc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t4@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t4.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t4@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Newcastle United
#         </span>
#        </div>
#        <span class="name">
#         Newcastle United
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.sufc.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t49@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t49.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t49@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Sheffield United
#         </span>
#        </div>
#        <span class="name">
#         Sheffield United
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.southamptonfc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t20@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t20.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t20@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Southampton
#         </span>
#        </div>
#        <span class="name">
#         Southampton
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.tottenhamhotspur.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t6@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t6.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t6@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Tottenham Hotspur
#         </span>
#        </div>
#        <span class="name">
#         Tottenham Hotspur
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.wba.co.uk?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t35.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t35@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t35.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t35@x2.png 2x"/>
#         <span class="visuallyHidden">
#          West Bromwich Albion
#         </span>
#        </div>
#        <span class="name">
#         West Bromwich Albion
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        http://www.whufc.com/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t21@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t21.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t21@x2.png 2x"/>
#         <span class="visuallyHidden">
#          West Ham United
#         </span>
#        </div>
#        <span class="name">
#         West Ham United
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="        https://www.wolves.co.uk/?utm_source=premier-league-website&amp;utm_campaign=website&amp;utm_medium=link
# " role="menuitem" target="_blank">
#        <div class="badge badge--small badge-image-container" data-size="25" data-widget="club-badge-image">
#         <img class="badge-image badge-image--25 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/25/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t39@x2.png 2x"/>
#        </div>
#        <div class="badge badge--large badge-image-container" data-size="50" data-widget="club-badge-image">
#         <img class="badge-image badge-image--50 js-badge-image" src="https://resources.premierleague.com/premierleague/badges/50/t39.png" srcset="https://resources.premierleague.com/premierleague/badges/50/t39@x2.png 2x"/>
#         <span class="visuallyHidden">
#          Wolverhampton Wanderers
#         </span>
#        </div>
#        <span class="name">
#         Wolverhampton Wanderers
#        </span>
#       </a>
#      </li>
#     </ul>
#    </nav>
#    <div class="fixedContainer">
#     <a aria-label="Premier League Home Page on logo link" class="u-hide-tab logoContainer" href="https://www.premierleague.com/home">
#      <svg class="logo" style="enable-background:new 0 0 131.1 166.7;" version="1.1" viewbox="0 0 131.1 166.7" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#       <style type="text/css">
#        .st0{fill:#360D3A;}
#       </style>
#       <path class="st0" d="M28.8,18.8c6.8,3.2,11.3,7.1,12.1,7.7c-0.3-1.8-1.7-10.3-2.6-15.5c3.9,2.7,13.3,9.2,16.3,11.3
#                 C55.8,18.5,60.2,6,60.2,6s7.8,12.5,9,14.6C70.9,19,80.1,8.6,82.5,6c0.5,5.9,0.9,14.5,1.1,15.7c0.5-0.6,4.1-5.6,10-10.3
#                 c-2.6,5.1-3.8,12.1-4.4,17.8c-5.9-1.7-12.1-2.6-18.4-2.6c-12.2,0-23.8,3.2-33.8,8.9C35.3,30,32.6,23.2,28.8,18.8z M122.6,126.2
#                 l-5.4-6c-1.5,16.1-9.5,29.9-24,39.5l-2.3-8.7c-12.4,8.9-33.5,14.6-51.7,4.4c2.3-11.5,4.2-23.2,0-37.2c-10.1,15.5-19,21.7-19,21.7
#                 c-6.8-11.5-6.2-34.4-4.2-41.2l-11.3,3.5c0-7.7,5.6-24,13.6-33.2l-6.9-1.1c4.8-9.8,11.9-18.2,20.8-24.7c-2.7,4.4-2.7,14.6,5,18.5
#                 c-3.3-5.7-3.6-12.8-0.3-16.6c3.5-3.8,9.2-2.4,12.8,0.5c-1.1-3.2-4.4-7.2-9-7.5c9-4.7,19.5-7.2,30.3-7.2c2.1,0,4.1,0.2,6,0.3
#                 c3.2,1.2,7.8,5.7,10,8.6c0,0,0.2-3.3-1.7-7.2c11.8,2.9,17.5,7.7,19.8,10c0.5,5.1,2,8.1,4.1,13c-3.8-4.2-13.4-11.2-18.1-12.8
#                 c0,0-0.5,4.4-2,6.5c-9.2-6.6-13.6-8.3-13.6-8.3C65.3,42,59,46,55.4,49l3,2.6c-6,1.8-10,7.1-10,7.1c0,0.2,5.4,0.9,5.4,0.9
#                 s-0.6,6.3,7.4,10.3c6.8,3.3,16.4-0.8,25.6,2.9c-6-6.9-10.1-10.1-10.1-10.1s-2.4-0.5-4.1-0.5c-2.1,0-5.3,0.5-8.6-0.9
#                 c-1.7-0.6-3.6-1.8-5-2.7c0,0,4.2-4.4,10.4-5.3c0,0,5.6,1.5,10,4.8c2.9-2.9,6-2.7,6-2.7s-3,2.9-2.1,6.2c4.4,3.9,9.2,9.5,9.2,9.5
#                 c4.8-2.7,15.4-2.1,17.6,0.5c-2.7-3.6-6.8-6.5-9.8-9c-0.3-1.4-3.8-6-4.2-6.5c0,0,3.2,1.1,6,3.5c0.8-1.2,2.4-2.4,4.4-2.9
#                 c2.1,1.8,2.6,4.5,2.4,5c-0.9,1.2-2,1.7-2,1.7l5.1,5.6l0.5-4.1C124.4,81.8,130.9,101.5,122.6,126.2z M100.2,89.7v-8.7
#                 c0,0-3.9-1.2-8.1-4.5c-8.4,1.2-18.5,9.7-18.5,9.7s3.5,6.5,7.2,13.6C87.4,100.5,97.2,92.3,100.2,89.7z M108.6,105.5
#                 c0,0-0.6-3.6-3.6-6.9l-6.5,0.2c0,0-8.9,7.5-14.2,7.7c0,0,3,5.6,4.5,8.4c3-0.6,8.1-3,10.3-5.4c0,0,1.4,4.5,1.1,9.8
#                 C103.2,117.4,107.3,112.8,108.6,105.5z M111.3,76.7c-3.3,2.7-6,4.4-6,4.4v8.7c2.4,2.6,4.7,4.8,6.5,8.7
#                 C115.1,92.7,114.3,84,111.3,76.7z">
#       </path>
#      </svg>
#      <div class="logoBackground">
#      </div>
#      <span class="mobile">
#       <img alt="Premier League Logo" src="/resources/prod/83c6d67-3434/i/elements/premier-league-logo-header-mob.svg"/>
#      </span>
#     </a>
#     <div class="navContainer" data-script="pl_global-header">
#      <section class="navBar" id="mainNav" role="menubar">
#       <div aria-expanded="false" class="menuBtn" id="hamburgerToggle" role="button">
#        <div class="menuBtnContainer">
#         <div>
#         </div>
#         <div>
#         </div>
#         <div>
#         </div>
#        </div>
#       </div>
#       <nav class="mainNav">
#        <ul class="pageLinks" role="menu">
#         <li aria-haspopup="true" class="premierleague" role="menuitem" tabindex="0">
#          <div class="navLink active" role="button" tabindex="index">
#           <span class="navText">
#            Premier League
#           </span>
#           <span class="icn chevron-dropdown">
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown">
#           <ul role="menu">
#            <li tabindex="-1">
#             <a href="/home" role="menuitem" tabindex="0">
#              Home
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/fixtures" role="menuitem" tabindex="0">
#              Fixtures
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/results" role="menuitem" tabindex="0">
#              Results
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/tables" role="menuitem" tabindex="0">
#              Tables
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/transfers" role="menuitem" tabindex="0">
#              Transfers
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/broadcast-schedules" role="menuitem" tabindex="0">
#              Broadcast
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/tickets" role="menuitem" tabindex="0">
#              Tickets
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/clubs" role="menuitem" tabindex="0">
#              Clubs
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/players" role="menuitem" tabindex="0">
#              Players
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/managers" role="menuitem" tabindex="0">
#              Managers
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/news" role="menuitem" tabindex="0">
#              News
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/social" role="menuitem" tabindex="0">
#              Social
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/youth" role="menuitem" tabindex="0">
#              Youth
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/safeguarding" role="menuitem" tabindex="0">
#              Safeguarding
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/history" role="menuitem" tabindex="0">
#              History
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/referees/overview" role="menuitem" tabindex="0">
#              Referees
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="fantasy" role="menuitem">
#          <div class="navLink" role="button" tabindex="index">
#           <span class="navText">
#            Fantasy
#           </span>
#           <span class="icn chevron-dropdown">
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown">
#           <ul role="menu">
#            <li tabindex="-1">
#             <a href="/fantasy" role="menuitem" tabindex="0">
#              Fantasy
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/draft" role="menuitem" tabindex="0">
#              Fantasy Draft
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="video" role="menuitem">
#          <a class="navLink" data-link-index="2" href="/video" role="menuitem">
#           Video
#          </a>
#          <div class="navLink mobile" role="button" tabindex="index">
#           <span class="navText">
#            Video
#           </span>
#           <span class="icn chevron-dropdown">
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown dropdownMobile">
#           <ul role="menu">
#            <li tabindex="-1">
#             <a href="/video" role="menuitem" tabindex="0">
#              Dashboard
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/video/fantasy" role="menuitem" tabindex="0">
#              Fantasy
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/video/all" role="menuitem" tabindex="0">
#              All Videos
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/video/playlists" role="menuitem" tabindex="0">
#              Playlists
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="communities" role="menuitem" tabindex="0">
#          <div class="navLink" role="button" tabindex="index">
#           <span class="navText">
#            Communities
#           </span>
#           <span class="icn chevron-dropdown">
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown">
#           <ul role="menu">
#            <li tabindex="-1">
#             <a href="/communities" role="menuitem" tabindex="0">
#              Latest
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/communities/strategy" role="menuitem" tabindex="0">
#              Strategy
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/communities/programmes" role="menuitem" tabindex="0">
#              Programmes
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/communities/facilities" role="menuitem" tabindex="0">
#              Facilities
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/communities/plcf" role="menuitem" tabindex="0">
#              PL Charitable Fund
#             </a>
#            </li>
#            <li tabindex="-1">
#             <a href="/communities/supporting-the-game" role="menuitem" tabindex="0">
#              Supporting the Game
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="show-ms noroomforracism noDrop" role="menuitem">
#          <a class="navLink" data-link-index="25" href="/NoRoomForRacism" role="menuitem">
#           No Room For Racism
#          </a>
#          <div class="navLink" data-nochildrenlink="/NoRoomForRacism" role="button" tabindex="index">
#           <span class="navText">
#            No Room For Racism
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown">
#          </div>
#         </li>
#         <li aria-haspopup="true" class="more" role="menuitem" tabindex="0">
#          <div class="navLink" role="button">
#           More
#           <span class="icn chevron-dropdown">
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown">
#           <ul role="menu">
#            <li>
#             <a href="/stats" role="menuitem">
#              Stats
#             </a>
#            </li>
#            <li>
#             <a href="/stay-well" role="menuitem">
#              Stay Well
#             </a>
#            </li>
#            <li>
#             <a href="/coronavirus" role="menuitem">
#              We Are One Team
#             </a>
#            </li>
#            <li>
#             <a href="/RainbowLaces" role="menuitem">
#              Rainbow Laces
#             </a>
#            </li>
#            <li>
#             <a href="/king-of-the-match" role="menuitem">
#              King of the Match
#             </a>
#            </li>
#            <li>
#             <a href="/transfers" role="menuitem">
#              Transfers
#             </a>
#            </li>
#            <li>
#             <a href="/VAR" role="menuitem">
#              VAR
#             </a>
#            </li>
#            <li>
#             <a href="/photos" role="menuitem">
#              Photos
#             </a>
#            </li>
#            <li>
#             <a href="/partners" role="menuitem">
#              Partners
#             </a>
#            </li>
#            <li>
#             <a href="/usa-bar-finder" role="menuitem">
#              USA Bar Finder
#             </a>
#            </li>
#            <li>
#             <a href="/epl" role="menuitem">
#              ePremier League
#             </a>
#            </li>
#            <li>
#             <a href="/about" role="menuitem">
#              About
#             </a>
#            </li>
#            <li>
#             <a href="/season-review" role="menuitem">
#              Season Review
#             </a>
#            </li>
#            <li>
#             <a href="/nike-ball-hub" role="menuitem">
#              Nike Ball Hub
#             </a>
#            </li>
#            <li>
#             <a href="/contact" role="menuitem">
#              Contact Us
#             </a>
#            </li>
#            <li>
#             <a href="/poppy" role="menuitem">
#              Poppy
#             </a>
#            </li>
#            <li>
#             <a href="/asia-trophy" role="menuitem">
#              Asia Trophy
#             </a>
#            </li>
#            <li>
#             <a href="/pl-live" role="menuitem">
#              PL Live
#             </a>
#            </li>
#            <li>
#             <a href="/publications" role="menuitem">
#              Publications
#             </a>
#            </li>
#            <li>
#             <a href="/legal" role="menuitem">
#              Legal
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <!--TO-TRANSLATE -->
#         <li aria-haspopup="true" class="clubs">
#          <div class="navLink clubListMobileButton" role="button">
#           Clubs
#           <span class="icn external-w">
#            <span class="visuallyHidden">
#             External Link
#            </span>
#           </span>
#          </div>
#          <div aria-hidden="true" class="dropdown" role="menu">
#          </div>
#         </li>
#        </ul>
#       </nav>
#       <div class="navOption search">
#        <div class="searchBtn headerSearchButton" role="button" tabindex="0">
#         <span class="visuallyHidden">
#          Search
#         </span>
#         <div alt="" class="icn search-w">
#         </div>
#        </div>
#       </div>
#       <a class="navLink navOption navOption--no-border fantasySignIn" href="#!" role="button" tabindex="0">
#        <span class="fantasySignInLabel">
#         Sign in
#        </span>
#       </a>
#       <a class="navLink navOption navOption--no-border fantasySignOut" href="#!" role="button" tabindex="0">
#        <span class="fantasyUsername">
#        </span>
#       </a>
#       <a class="noroomforracism hide-ms navLink navOption" href="/NoRoomForRacism" role="button" tabindex="0">
#        <div class="icn user-w show-m">
#        </div>
#        <span class="featuredLinkTitle">
#         No Room For Racism
#        </span>
#       </a>
#       <span class="mobile-logo">
#        <a aria-label="Premier League Home Page on logo link" class="u-show-tab" href="https://www.premierleague.com/home">
#         <i class="icn pl-logo-mobile-menu">
#         </i>
#        </a>
#       </span>
#      </section>
#      <div class="searchBar searchBarContainer" data-widget="search-header-redirect" role="search">
#       <div class="searchBox">
#        <div class="plSearch">
#         <input class="searchInput searchInputContainer" id="searchPremierLeagueInput" placeholder="Search Premier League" type="text"/>
#         <label class="visuallyHidden" for="searchPremierLeagueInput">
#          Search Premier League
#         </label>
#         <span class="focusBorder">
#         </span>
#         <span class="searchBtnContainer searchButtonContainer">
#          <input aria-label="Submit search" class="searchInputBtn" id="searchPremierLeagueInput" tabindex="0" type="submit"/>
#          <span class="btnBg">
#          </span>
#          <span class="icn search-sm">
#           <span class="visuallyHidden">
#            Submit search
#           </span>
#          </span>
#         </span>
#        </div>
#       </div>
#      </div>
#      <div class="searchOverlay">
#      </div>
#     </div>
#     <nav class="subNav" role="menubar">
#      <ul>
#       <li>
#        <a class="" data-link-index="0" href="/home" role="menuitem">
#         Home
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="1" href="/fixtures" role="menuitem">
#         Fixtures
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="2" href="/results" role="menuitem">
#         Results
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="3" href="/tables" role="menuitem">
#         Tables
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="4" href="/transfers" role="menuitem">
#         Transfers
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="5" href="/broadcast-schedules" role="menuitem">
#         Broadcast
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="6" href="/tickets" role="menuitem">
#         Tickets
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="7" href="/clubs" role="menuitem">
#         Clubs
#        </a>
#       </li>
#       <li>
#        <a class="active" data-link-index="8" href="/players" role="menuitem">
#         Players
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="9" href="/managers" role="menuitem">
#         Managers
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="10" href="/news" role="menuitem">
#         News
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="11" href="/social" role="menuitem">
#         Social
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="12" href="/youth" role="menuitem">
#         Youth
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="13" href="/safeguarding" role="menuitem">
#         Safeguarding
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="14" href="/history" role="menuitem">
#         History
#        </a>
#       </li>
#       <li>
#        <a class="" data-link-index="15" href="/referees/overview" role="menuitem">
#         Referees
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </div>
#   </header>
#   <main id="mainContent" tabindex="0">
#    <!-- /131332370/GeneralTakeover_0 -->
#    <div class="ad-takeover js-ad-takeover">
#     <nav class="navBar">
#      <a class="plLogo" href="#!" id="logoClose">
#       <img alt="Premier League Logo" src="/resources/prod/83c6d67-3434/i/elements/premier-league-logo-header-full.png"/>
#      </a>
#      <a class="closeBtn" href="#!" id="advertClose">
#       Close Advert
#      </a>
#     </nav>
#     <div class="DFP-takeover" id="div-gpt-ad-1503491171981-0" style="display: none;">
#     </div>
#     <script type="text/javascript">
#      // GOOGLE ADS SCRIPT
#         var adWrap = document.querySelector('.js-ad-takeover');
#         var slotId = '/131332370/GeneralTakeover_0';
#
#         googletag.cmd.push(function() {
#
#             var mapping = googletag.sizeMapping().
#             addSize([0, 0], []).
#             addSize([200, 300], [[320, 50], [320, 480]]).
#             addSize([450, 300], [[320, 50], [1600, 900]]).
#             addSize([750, 300], [[728, 90], [1600, 900]]).
#             addSize([990, 300], [[1600, 900], [970, 250], [728, 90]]).build();
#
#             googletag.defineSlot('/131332370/GeneralTakeover', [
#                 [1600, 900],
#                 [320, 480]
#             ], 'div-gpt-ad-1503491171981-0').
#                 defineSizeMapping(mapping).
#                 addService(googletag.pubads());
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#
#             googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#
#                 if ( slotId === event.slot.getSlotId().toString() ) {
#                     if (event.isEmpty) {
#                         adWrap.style.display = 'none';
#                     } else {
#                         adWrap.style.display = 'block';
#                     }
#                 }
#             });
#
#             googletag.display('div-gpt-ad-1503491171981-0');
#
#         });
#
#         // PULSELIVE SCRIPT
#         var closeBtn = document.getElementById('advertClose');
#         var closeLogo = document.getElementById('logoClose');
#
#         closeBtn.addEventListener('click', function( e ){
#             e.preventDefault();
#             adWrap.innerHTML = "";
#             adWrap.style.width = 0;
#             adWrap.style.height = 0;
#         });
#
#         closeLogo.addEventListener('click', function( e ){
#             e.preventDefault();
#             adWrap.innerHTML = "";
#             adWrap.style.width = 0;
#             adWrap.style.height = 0;
#         });
#     </script>
#    </div>
#    <section class="playerHero t-gradient-background t43-bg" data-club-id="11" data-widget="local-club">
#     <div class="playerHero__bg-shape-container">
#      <svg class="playerHero__bg-shape t-fill u-hide-tab" viewbox="0 0 1496 270" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M1496 6.3c-194.1 93.7-427.6 160.3-645.2 183.2L993.8 46C884.6 66.3 806.4 69.9 691.4 69.9c-66.4 0-129.7-3.4-192-10.1s-123.6-16.9-186-30.3L342.7 0H0v67.3c68.3 26.5 138.4 49.4 208.5 67.5l-85.1 85.5C184.5 240 249.3 256.5 316 270h1180V6.3z" fill-rule="evenodd">
#       </path>
#      </svg>
#      <svg class="playerHero__bg-shape playerHero__bg-shape--mobile t-fill u-show-tab" enable-background="new 0 0 375 188" viewbox="0 0 375 188" xmlns="http://www.w3.org/2000/svg">
# ...
#          <span class="link">
#           My Team
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://fantasy.premierleague.com/a/squad/transfers" role="menuitem" target="_blank">
#          <span class="link">
#           FPL Transfers
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://fantasy.premierleague.com/a/leagues/main" role="menuitem" target="_blank">
#          <span class="link">
#           Leagues
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://fantasy.premierleague.com/a/fixtures" role="menuitem" target="_blank">
#          <span class="link">
#           FPL Fixtures
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://fantasy.premierleague.com/a/statistics/total_points" role="menuitem" target="_blank">
#          <span class="link">
#           Statistics
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://fantasy.premierleague.com/the-scout" role="menuitem" target="_blank">
#          <span class="link">
#           The Scout
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footerCol">
#       <h3 class="subHeader">
#        Stats
#       </h3>
#       <ul class="list--stats" role="menu">
#        <li>
#         <a href="//www.premierleague.com/stats" role="menuitem" target="_self">
#          <span class="link">
#           Dashboard
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/top/players/goals?se=54" role="menuitem" target="_self">
#          <span class="link">
#           Player Stats
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/top/clubs/wins?se=54" role="menuitem" target="_self">
#          <span class="link">
#           Club Stats
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/all-time" role="menuitem" target="_self">
#          <span class="link">
#           All-time Stats
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/records" role="menuitem" target="_self">
#          <span class="link">
#           Records
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/head-to-head" role="menuitem" target="_self">
#          <span class="link">
#           Head-to-Head
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/player-comparison" role="menuitem" target="_self">
#          <span class="link">
#           Player Comparison
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/stats/awards" role="menuitem" target="_self">
#          <span class="link">
#           Awards
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footerCol">
#       <h3 class="subHeader">
#        Video
#       </h3>
#       <ul class="list--video" role="menu">
#        <li>
#         <a href="//www.premierleague.com/video" role="menuitem" target="_self">
#          <span class="link">
#           Latest Videos
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footerCol">
#       <h3 class="subHeader">
#        Communities
#       </h3>
#       <ul class="list--communities" role="menu">
#        <li>
#         <a href="//www.premierleague.com/communities" role="menuitem" target="_self">
#          <span class="link">
#           Latest
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/communities/programmes" role="menuitem" target="_self">
#          <span class="link">
#           Programmes
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/communities/PLKicksheroes" role="menuitem" target="_self">
#          <span class="link">
#           PL Kicks Heroes
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/communities/strategy" role="menuitem" target="_self">
#          <span class="link">
#           Strategy
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://plprimarystars.com/" role="menuitem" target="_blank">
#          <span class="link">
#           PL Primary Stars
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footerCol">
#       <h3 class="subHeader">
#        More
#       </h3>
#       <ul class="list--more" role="menu">
#        <li>
#         <a href="//www.premierleague.com/stay-well" role="menuitem" target="_self">
#          <span class="link">
#           Stay Well
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/NoRoomForRacism" role="menuitem" target="_self">
#          <span class="link">
#           No Room for Racism
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/RainbowLaces" role="menuitem" target="_self">
#          <span class="link">
#           Rainbow Laces
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/king-of-the-match" role="menuitem" target="_self">
#          <span class="link">
#           King of the Match
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/transfers" role="menuitem" target="_self">
#          <span class="link">
#           Transfers
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/VAR" role="menuitem" target="_self">
#          <span class="link">
#           VAR
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/photos" role="menuitem" target="_self">
#          <span class="link">
#           Photos
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/partners" role="menuitem" target="_self">
#          <span class="link">
#           Partners
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/epl" role="menuitem" target="_self">
#          <span class="link">
#           ePremier League
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/season-review" role="menuitem" target="_self">
#          <span class="link">
#           Season Review
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/about" role="menuitem" target="_self">
#          <span class="link">
#           About
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/nike-ball-hub" role="menuitem" target="_self">
#          <span class="link">
#           Nike Ball Hub
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/contact" role="menuitem" target="_self">
#          <span class="link">
#           Contact Us
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/poppy" role="menuitem" target="_self">
#          <span class="link">
#           Poppy
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/asia-trophy" role="menuitem" target="_self">
#          <span class="link">
#           Asia Trophy
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/pl-live" role="menuitem" target="_self">
#          <span class="link">
#           PL Live
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/publications" role="menuitem" target="_self">
#          <span class="link">
#           Publications
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="//www.premierleague.com/legal" role="menuitem" target="_self">
#          <span class="link">
#           Legal
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footerCol">
#       <h3 class="subHeader">
#        Social
#       </h3>
#       <ul class="list--social" role="menu">
#        <li>
#         <a href="https://www.youtube.com/premierleague" role="menuitem" target="_blank">
#          <span class="link">
#           PL on YouTube
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.facebook.com/premierleague" role="menuitem" target="_blank">
#          <span class="link">
#           PL on Facebook
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.facebook.com/OfficialFPL/" role="menuitem" target="_blank">
#          <span class="link">
#           FPL on Facebook
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/premierleague" role="menuitem" target="_blank">
#          <span class="link">
#           PL on Twitter
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/OfficialFPL" role="menuitem" target="_blank">
#          <span class="link">
#           FPL on Twitter
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/PLCommunities" role="menuitem" target="_blank">
#          <span class="link">
#           PL Communities on Twitter
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/PLYouth" role="menuitem" target="_blank">
#          <span class="link">
#           PL Youth on Twitter
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/premierleague" role="menuitem" target="_blank">
#          <span class="link">
#           PL on Instagram
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/PLinUSA" role="menuitem" target="_blank">
#          <span class="link">
#           PL USA on Twitter
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/plinusa/" role="menuitem" target="_blank">
#          <span class="link">
#           PL USA on Instagram
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="https://open.spotify.com/user/plplaylists" role="menuitem" target="_blank">
#          <span class="link">
#           PL Music on Spotify
#          </span>
#          <span class="icn external-sm-pink">
#           <span class="visuallyHidden">
#            External Link
#           </span>
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="footerCorporate" data-script="pl_footer" data-widget="footer-corporate">
#     <div class="wrapper col-12">
#      <ul role="menu">
#       <li>
#        <strong class="">
#         © PREMIER LEAGUE 2021
#        </strong>
#       </li>
#       <li>
#        <a class="" href="//www.premierleague.com/modern-slavery-statement" role="menuitem">
#         Modern Slavery Statement
#        </a>
#       </li>
#       <li>
#        <a class="" href="//www.premierleague.com/equality-diversity-and-inclusion-standard" role="menuitem">
#         Equality, Diversity and Inclusion Standard
#        </a>
#       </li>
#       <li>
#        <a class="" href="//www.premierleague.com/terms-and-conditions" role="menuitem">
#         Terms &amp; Conditions
#        </a>
#       </li>
#       <li>
#        <a class="" href="//www.premierleague.com/premier-league-policies" role="menuitem">
#         Policies
#        </a>
#       </li>
#       <li>
#        <a class="" href="//www.premierleague.com/cookie-policy" role="menuitem">
#         Cookie Policy
#        </a>
#       </li>
#       <li>
#        <a class="backToTopContainer" href="//www.premierleague.com#" role="menuitem">
#         Back To Top
#        </a>
#       </li>
#      </ul>
#      <div class="official">
#       <a class="icn pl-logo-corporate" href="//www.premierleague.com/home">
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script src="/resources/prod/83c6d67-3434/bower/pulse-js/dist/pulse.min.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/scripts/main.min.js">
#   </script>
#   <script src="/resources/prod/83c6d67-3434/widgets/common.min.js">
#   </script>
#   <!-- S3 -->
#   <!-- Adform tracking code begin -->
#   <script type="text/javascript">
#    (function() {
#     var adfScr = document.createElement("script");
#     adfScr.src = "https://track.adform.net/serving/scripts/trackpoint/";
#     adfScr.onload = function() {
#         adf.container(998269, 'Master Tag');
#     };
#     document.head.appendChild(adfScr);
# })();
#   </script>
#   <!-- Adform tracking code end -->
#   <section class="js-cookies-notice cookies-notice u-hide">
#    <div class="wrapper col-12">
#     <h3 class="subHeader">
#      Cookies on PremierLeague.com
#     </h3>
#     <p>
#      The Premier League website employs cookies to make our website work and improve your user experience. Essential cookies are required for the operation of our website. You may disable these but this may affect website functionality. Non-essential cookies help us improve the functionality of our website by collecting information and reporting on your use of the website as well as improving your user experience. You can manage your cookie settings and switch off non-essential cookies via the “Manage Settings” below.
#     </p>
#     <a class="btn-primary cookiesInfo" href="/cookie-policy">
#      Manage Settings
#      <span class="icn arrow-rightwhite">
#      </span>
#     </a>
#     <div class="btn-primary cookies-notice-accept" role="btn" tabindex="0">
#      I accept cookies from this site
#      <span class="icn tick-w">
#      </span>
#     </div>
#    </div>
#   </section>
#  </body>
# </html>

# %%
new = soup.find("ul", class_ = "normalStatList")
new.get_text()
# Out:
# '\n\n\n\nDefence\n\n\nClean sheets   \n      13\n  \n\n\n\nGoals Conceded   \n      11\n  \n\n\n\nTackles   \n      19\n  \n\n\n\nTackle success %   \n        63%\n  \n\n\n\nLast man tackles   \n      0\n  \n\n\n\nBlocked shots   \n      1\n  \n\n\n\nInterceptions   \n      24\n  \n\n\n\nClearances   \n      68\n  \n\n\n\nHeaded Clearance   \n      36\n  \n\n\n\nClearances off line   \n      0\n  \n\n\n\nRecoveries   \n      106\n  \n\n\n\nDuels won   \n      90\n  \n\n\n\nDuels lost   \n      52\n  \n\n\n\nSuccessful 50/50s   \n      6\n  \n\n\n\nAerial battles won   \n      51\n  \n\n\n\nAerial battles lost   \n      27\n  \n\n\n\nOwn goals   \n      1\n  \n\n\n\nErrors leading to goal   \n      0\n  \n\n\n\n\n\n\n\nTeam Play\n\n\nAssists   \n      0\n  \n\n\n\nPasses   \n      2,046\n  \n\n\n\nPasses per match   \n        85.25\n  \n\n\n\nBig Chances Created   \n      0\n  \n\n\n\nCrosses   \n      0\n  \n\n\n\nCross accuracy %   \n        0%\n  \n\n\n\nThrough balls   \n      1\n  \n\n\n\nAccurate long balls   \n      81\n  \n\n\n\n\n\n\n\nDiscipline\n\n\nYellow cards   \n      3\n  \n\n\n\nRed cards   \n      0\n  \n\n\n\nFouls   \n      16\n  \n\n\n\nOffsides   \n      1\n  \n\n\n\n\n\n\n\nAttack\n\n\nGoals   \n      1\n  \n\n\n\nHeaded goals   \n      1\n  \n\n\n\nGoals with right foot   \n      0\n  \n\n\n\nGoals with left foot   \n      0\n  \n\n\n\nHit woodwork   \n      0\n  \n\n\n\n\n'

# %%
new2 = new.get_text().replace('\n',' ').split()
new2
# Out:
# ['Defence',
#  'Clean',
#  'sheets',
#  '13',
#  'Goals',
#  'Conceded',
#  '11',
#  'Tackles',
#  '19',
#  'Tackle',
#  'success',
#  '%',
#  '63%',
#  'Last',
#  'man',
#  'tackles',
#  '0',
#  'Blocked',
#  'shots',
#  '1',
#  'Interceptions',
#  '24',
#  'Clearances',
#  '68',
#  'Headed',
#  'Clearance',
#  '36',
#  'Clearances',
#  'off',
#  'line',
#  '0',
#  'Recoveries',
#  '106',
#  'Duels',
#  'won',
#  '90',
#  'Duels',
#  'lost',
#  '52',
#  'Successful',
#  '50/50s',
#  '6',
#  'Aerial',
#  'battles',
#  'won',
#  '51',
#  'Aerial',
#  'battles',
#  'lost',
#  '27',
#  'Own',
#  'goals',
#  '1',
#  'Errors',
#  'leading',
#  'to',
#  'goal',
#  '0',
#  'Team',
#  'Play',
#  'Assists',
#  '0',
#  'Passes',
#  '2,046',
#  'Passes',
#  'per',
#  'match',
#  '85.25',
#  'Big',
#  'Chances',
#  'Created',
#  '0',
#  'Crosses',
#  '0',
#  'Cross',
#  'accuracy',
#  '%',
#  '0%',
#  'Through',
#  'balls',
#  '1',
#  'Accurate',
#  'long',
#  'balls',
#  '81',
#  'Discipline',
#  'Yellow',
#  'cards',
#  '3',
#  'Red',
#  'cards',
#  '0',
#  'Fouls',
#  '16',
#  'Offsides',
#  '1',
#  'Attack',
#  'Goals',
#  '1',
#  'Headed',
#  'goals',
#  '1',
#  'Goals',
#  'with',
#  'right',
#  'foot',
#  '0',
#  'Goals',
#  'with',
#  'left',
#  'foot',
#  '0',
#  'Hit',
#  'woodwork',
#  '0']
